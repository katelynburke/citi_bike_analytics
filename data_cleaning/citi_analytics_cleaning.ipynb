# %%
import pandas as pd

# %%
# Jan 18
file = "../resources/1_18_tripdata.csv"

jan_18 = pd.read_csv(file)
jan_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           932   06:17.5  21:50.0              3183     Exchange Place
# 1           550   06:18.0  15:28.4              3183     Exchange Place
# 2           510   06:57.0  15:27.8              3183     Exchange Place
# 3           354   53:10.2  59:05.1              3183     Exchange Place
# 4           250   34:30.2  38:41.0              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3199
# 2               40.716247               -74.033459            3199
# 3               40.716247               -74.033459            3267
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Feb 18
file1 = "../resources/2_18_tripdata.csv"

feb_18 = pd.read_csv(file1)
feb_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           134   38:15.9  40:30.6              3183     Exchange Place
# 1           413   19:35.8  26:29.6              3183     Exchange Place
# 2            77   31:03.1  32:20.4              3183     Exchange Place
# 3           404   23:15.1  29:59.9              3183     Exchange Place
# 4           230   26:01.8  29:52.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3184
# 1               40.716247               -74.033459            3267
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3267
# 4               40.716247               -74.033459            3213
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# March 18
file2 = "../resources/3_18_tripdata.csv"

mar_18 = pd.read_csv(file2)
mar_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           329   37:37.0  43:06.6              3183     Exchange Place
# 1           118   37:30.1  39:28.4              3183     Exchange Place
# 2            76   26:17.9  27:34.7              3183     Exchange Place
# 3           578   10:36.2  20:14.9              3183     Exchange Place
# 4           485   21:47.9  29:53.3              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3202
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3185
# 4               40.716247               -74.033459            3187
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# April 18
file3 = "../resources/4_18_tripdata.csv"

apr_18 = pd.read_csv(file3)
apr_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0          1814   43:51.2  14:06.1              3183     Exchange Place
# 1           298   42:53.7  47:51.9              3183     Exchange Place
# 2          1060   43:12.0  00:52.9              3183     Exchange Place
# 3          1035   43:40.6  00:55.7              3183     Exchange Place
# 4           559   56:47.5  06:06.8              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3638
# 1               40.716247               -74.033459            3187
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3192
# 4               40.716247               -74.033459            3199
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# May 18
file4 = "../resources/5_18_tripdata.csv"

may_18 = pd.read_csv(file4)
may_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           131   29:57.5  32:08.6              3183     Exchange Place
# 1            73   13:58.3  15:11.9              3183     Exchange Place
# 2          4929   17:21.3  39:31.1              3183     Exchange Place
# 3           432   25:58.7  33:10.9              3183     Exchange Place
# 4           432   28:09.9  35:22.1              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3184
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3183
# 3               40.716247               -74.033459            3202
# 4               40.716247               -74.033459            3638
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# June 18
file5 = "../resources/6_18_tripdata.csv"

jun_18 = pd.read_csv(file5)
jun_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           329   07:00.3  12:30.2              3183     Exchange Place
# 1           259   24:43.8  29:03.8              3183     Exchange Place
# 2           686   17:49.6  29:16.2              3183     Exchange Place
# 3           164   44:00.4  46:44.7              3183     Exchange Place
# 4           769   59:28.8  12:18.7              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3276
# 1               40.716247               -74.033459            3267
# 2               40.716247               -74.033459            3202
# 3               40.716247               -74.033459            3267
# 4               40.716247               -74.033459            3203
#
#    end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# July 18 
file6 = "../resources/7_18_tripdata.csv"

jul_18 = pd.read_csv(file6)
jul_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0          1234   08:39.9  29:14.5              3183     Exchange Place
# 1          1041   09:07.5  26:28.9              3183     Exchange Place
# 2          2308   14:45.7  53:14.6              3183     Exchange Place
# 3           767   25:12.4  38:00.1              3183     Exchange Place
# 4           151   07:44.1  10:15.8              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3183
# 1               40.716247               -74.033459            3183
# 2               40.716247               -74.033459            3183
# 3               40.716247               -74.033459            3183
# 4               40.716247               -74.033459            3275
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# August 18
file7 = "../resources/8_18_tripdata.csv"

aug_18 = pd.read_csv(file7)
aug_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           903   40:33.4  55:37.1              3183     Exchange Place
# 1            78   21:00.1  22:18.6              3183     Exchange Place
# 2           405   43:52.5  50:37.6              3183     Exchange Place
# 3           155   48:24.9  51:00.9              3183     Exchange Place
# 4           453   15:35.1  23:08.9              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3270
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3202
# 3               40.716247               -74.033459            3275
# 4               40.716247               -74.033459            3273
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Sept 18
file8 = "../resources/9_18_tripdata.csv"

sep_18 = pd.read_csv(file8)
sep_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           284   48:22.0  53:06.9              3183     Exchange Place
# 1           370   48:22.5  54:32.9              3183     Exchange Place
# 2          1181   37:04.3  56:45.3              3183     Exchange Place
# 3           383   44:46.0  51:09.9              3183     Exchange Place
# 4           377   44:46.2  51:03.6              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3267
# 1               40.716247               -74.033459            3214
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3213
# 4               40.716247               -74.033459            3213
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Oct 18
file9 = "../resources/10_18_tripdata.csv"

oct_18 = pd.read_csv(file9)
oct_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           152   44:41.4  47:14.3              3183     Exchange Place
# 1           122   50:05.4  52:08.2              3183     Exchange Place
# 2           211   03:17.1  06:48.1              3183     Exchange Place
# 3           342   13:07.0  18:49.9              3183     Exchange Place
# 4          2976   45:14.3  34:51.3              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3639
# 1               40.716247               -74.033459            3214
# 2               40.716247               -74.033459            3187
# 3               40.716247               -74.033459            3202
# 4               40.716247               -74.033459            3183
#
#    end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Nov 18
file10 = "../resources/11_18_tripdata.csv"

nov_18 = pd.read_csv(file10)
nov_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0          1188   32:27.5  52:15.9              3183     Exchange Place
# 1           278   14:31.9  19:10.3              3183     Exchange Place
# 2           115   33:17.2  35:12.3              3183     Exchange Place
# 3           155   20:10.9  22:46.7              3183     Exchange Place
# 4            82   35:02.8  36:25.2              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3202
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3681
# 4               40.716247               -74.033459            3184
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Dec 18
file11 = "../resources/12_18_tripdata.csv"

dec_18 = pd.read_csv(file11)
dec_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           170   03:53.4  06:43.7              3183     Exchange Place
# 1           172   47:13.7  50:05.8              3183     Exchange Place
# 2           247   48:57.7  53:05.7              3183     Exchange Place
# 3           406   33:53.7  40:39.7              3183     Exchange Place
# 4           354   26:52.5  32:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3481
# 2               40.716247               -74.033459            3267
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3211
#
#    end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Jan 19
file12 = "../resources/1_19_tripdata.csv"

jan_19 = pd.read_csv(file12)
jan_19.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           201   09:09.7  12:30.9              3183     Exchange Place
# 1           505   18:00.1  26:25.9              3183     Exchange Place
# 2           756   36:33.3  49:10.3              3183     Exchange Place
# 3          1575   43:38.6  09:54.5              3183     Exchange Place
# 4          1566   43:39.6  09:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3638
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3638
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Feb 19
file13 = "../resources/2_19_tripdata.csv"

feb_19 = pd.read_csv(file13)
feb_19.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           142   35:02.1  37:24.1              3183     Exchange Place
# 1           223   00:46.9  04:30.5              3183     Exchange Place
# 2           106   08:01.3  09:47.4              3183     Exchange Place
# 3           370   09:31.2  15:41.7              3183     Exchange Place
# 4           315   19:53.2  25:09.1              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3639
# 1               40.716247               -74.033459            3681
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3211
# 4               40.716247               -74.033459            3273
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# March 19
file14 = "../resources/3_19_tripdata.csv"

mar_19 = pd.read_csv(file14)
mar_19.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           306   47:08.2  52:14.7              3183     Exchange Place
# 1           123   30:53.0  32:56.8              3183     Exchange Place
# 2           328   18:30.4  23:59.1              3183     Exchange Place
# 3            95   04:47.2  06:22.8              3183     Exchange Place
# 4           169   51:29.4  54:19.2              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3267
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3213
# 3               40.716247               -74.033459            3184
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# April 19
file15 = "../resources/4_19_tripdata.csv"

apr_19 = pd.read_csv(file15)
apr_19.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           107   48:04.8  49:52.4              3183     Exchange Place
# 1           493   41:09.7  49:23.0              3183     Exchange Place
# 2           512   27:07.9  35:40.9              3183     Exchange Place
# 3           196   07:38.2  10:54.6              3183     Exchange Place
# 4           463   19:24.7  27:08.6              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3184
# 1               40.716247               -74.033459            3187
# 2               40.716247               -74.033459            3202
# 3               40.716247               -74.033459            3214
# 4               40.716247               -74.033459            3273
#
#    end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# May 19
file16 = "../resources/5_19_tripdata.csv"

may_19 = pd.read_csv(file16)
may_19.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           311   07:36.5  12:47.6              3185          City Hall
# 1           538   08:29.3  17:27.9              3681           Grand St
# 2           178   39:36.5  42:35.0              3638      Washington St
# 3           317   24:28.0  29:45.6              3206            Hilltop
# 4           354   54:39.7  00:34.2              3639         Harborside
#
#    start station latitude  start station longitude  end station id  \
# 0               40.717733               -74.043845            3279
# 1               40.715178               -74.037683            3203
# 2               40.724294               -74.035483            3639
# 3               40.731169               -74.057574            3212
# 4               40.719252               -74.034234            3202
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
may_19.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# Concat 2019 Data 

merged_19 = pd.concat([may_19, apr_19, mar_19, feb_19, jan_19])
merged_19.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           311   07:36.5  12:47.6              3185          City Hall
# 1           538   08:29.3  17:27.9              3681           Grand St
# 2           178   39:36.5  42:35.0              3638      Washington St
# 3           317   24:28.0  29:45.6              3206            Hilltop
# 4           354   54:39.7  00:34.2              3639         Harborside
#
#    start station latitude  start station longitude  end station id  \
# 0               40.717733               -74.043845            3279
# 1               40.715178               -74.037683            3203
# 2               40.724294               -74.035483            3639
# 3               40.731169               -74.057574            3212
# 4               40.719252               -74.034234            3202
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Concat 2018 Data
merged_18 = pd.concat([dec_18, nov_18, oct_18, sep_18, aug_18, jul_18, jun_18, may_18, apr_18, mar_18, feb_18, jan_18])
merged_18.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           170   03:53.4  06:43.7              3183     Exchange Place
# 1           172   47:13.7  50:05.8              3183     Exchange Place
# 2           247   48:57.7  53:05.7              3183     Exchange Place
# 3           406   33:53.7  40:39.7              3183     Exchange Place
# 4           354   26:52.5  32:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3481
# 2               40.716247               -74.033459            3267
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3211
#
#    end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
# Save new DF's
merged_19.to_csv('citi_bike_2019.csv', sep = ',')

# %%
merged_18.to_csv('citi_bike_2018.csv', sep = ',')
